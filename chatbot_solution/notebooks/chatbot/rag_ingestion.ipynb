# %%
import pandas as pd
import sqlite3
from Abastores_api import Abastores

# %%
client = Abastores()
df = client.dataprice()
# Out:
# INFO:root:Successfully retrieved data for page 1
# INFO:root:Successfully retrieved data for page 2
# INFO:root:Successfully retrieved data for page 3
# INFO:root:Successfully retrieved data for page 4
# INFO:root:Successfully retrieved data for page 5
# INFO:root:Successfully retrieved data for page 6
# INFO:root:Successfully retrieved data for page 7
# INFO:root:Successfully retrieved data for page 8
# INFO:root:Successfully retrieved data for page 9
# INFO:root:Successfully retrieved data for page 10
# INFO:root:Successfully retrieved data for page 11
# INFO:root:Successfully retrieved data for page 12
# INFO:root:Successfully retrieved data for page 13
# INFO:root:Successfully retrieved data for page 14
# INFO:root:Successfully retrieved data for page 15
# INFO:root:Successfully retrieved data for page 16
# INFO:root:Successfully retrieved data for page 17
# INFO:root:Successfully retrieved data for page 18
# INFO:root:Successfully retrieved data for page 19
# INFO:root:Successfully retrieved data for page 20
# INFO:root:Successfully retrieved data for page 21
# INFO:root:Successfully retrieved data for page 22
# INFO:root:Successfully retrieved data for page 23
# INFO:root:Successfully retrieved data for page 24
# INFO:root:Successfully retrieved data for page 25
# INFO:root:Successfully retrieved data for page 26
# INFO:root:Successfully retrieved data for page 27
# INFO:root:Successfully retrieved data for page 28
# INFO:root:Successfully retrieved data for page 29
# INFO:root:Successfully retrieved data for page 30
# INFO:root:Successfully retrieved data for page 31
# INFO:root:Successfully retrieved data for page 32
# INFO:root:Successfully retrieved data for page 33
# INFO:root:Successfully retrieved data for page 34
# INFO:root:Successfully retrieved data for page 35
# INFO:root:Successfully retrieved data for page 36
# INFO:root:Successfully retrieved data for page 37
# /Users/daniel/Desktop/Proyectos/agia/ChatGPT_Prototype/chatbot_rag_app/chatbot_solution/notebooks/Abastores_api.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(all_data, ignore_index=True)

# %%
df
# Out:
#            id                       date   price  quantity  region  \
# 0      181719  2024-05-29T12:45:00+02:00  217.00       NaN     NaN
# 1      181720  2024-05-29T12:45:00+02:00  270.00       NaN     NaN
# 2      181721  2024-05-29T12:45:00+02:00  188.00       NaN     NaN
# 3      181722  2024-05-29T12:45:00+02:00  218.00       NaN     NaN
# 4      181723  2024-05-29T12:45:00+02:00  227.00       NaN     NaN
# ...       ...                        ...     ...       ...     ...
# 36858   97321  2002-01-04T01:00:00+01:00  180.30       0.0    16.0
# 36859   97322  2002-01-04T01:00:00+01:00  147.25       0.0    16.0
# 36860   97323  2002-01-04T01:00:00+01:00  171.29       0.0    16.0
# 36861   97324  2002-01-04T01:00:00+01:00  153.26       0.0    16.0
# 36862   97325  2002-01-04T01:00:00+01:00  171.29       0.0    16.0
#
#        product.id  product.meta_product.id product.meta_product.name  \
# 0             554                       13                 Triticale
# 1           21907                        8                     Avena
# 2             547                        6                   Centeno
# 3           21758                        4                      Maíz
# 4               1                      284                     Trigo
# ...           ...                      ...                       ...
# 36858       21792                      284                     Trigo
# 36859       21886                      284                     Trigo
# 36860       21873                      284                     Trigo
# 36861       21890                      284                     Trigo
# 36862       21888                      284                     Trigo
#
#       product.meta_product.icon  product.family.id product.family.name  \
# 0                   a-triticale                  1            Cereales
# 1                         a-oat                  1            Cereales
# 2                         a-rye                  1            Cereales
# 3                        a-corn                  1            Cereales
# 4                       a-wheat                  1            Cereales
# ...                         ...                ...                 ...
# 36858                   a-wheat                  1            Cereales
# 36859                   a-wheat                  1            Cereales
# 36860                   a-wheat                  1            Cereales
# 36861                   a-wheat                  1            Cereales
# 36862                   a-wheat                  1            Cereales
#
#        product.variety.id product.variety.name  data_source.id  \
# 0                       1                Común              32
# 1                   15545               Pienso              32
# 2                   15371                Común              32
# 3                   15517             Nacional              32
# 4                   15557               Blando              32
# ...                   ...                  ...             ...
# 36858               15560                 Duro              36
# 36859               15545               Pienso              36
# 36860               15592  Fuerza +300w +14 pr              36
# 36861               15609          Panificable              36
# 36862               15608          Tipo Aragón              36
#
#       data_source.name                          data_source.link  \
# 0        Lonja de León      https://www.lonjadeleon.es/cereales/
# 1        Lonja de León      https://www.lonjadeleon.es/cereales/
# 2        Lonja de León      https://www.lonjadeleon.es/cereales/
# 3        Lonja de León      https://www.lonjadeleon.es/cereales/
# 4        Lonja de León      https://www.lonjadeleon.es/cereales/
# ...                ...                                       ...
# 36858  Lonja de Toledo  https://www.fedeto.es/lonja/cereales.htm
# 36859  Lonja de Toledo  https://www.fedeto.es/lonja/cereales.htm
# 36860  Lonja de Toledo  https://www.fedeto.es/lonja/cereales.htm
# 36861  Lonja de Toledo  https://www.fedeto.es/lonja/cereales.htm
# 36862  Lonja de Toledo  https://www.fedeto.es/lonja/cereales.htm
#
#       data_source.kind  province.id province.name
# 0             NATIONAL           14          León
# 1             NATIONAL           14          León
# 2             NATIONAL           14          León
# 3             NATIONAL           14          León
# 4             NATIONAL           14          León
# ...                ...          ...           ...
# 36858         NATIONAL            2        Toledo
# 36859         NATIONAL            2        Toledo
# 36860         NATIONAL            2        Toledo
# 36861         NATIONAL            2        Toledo
# 36862         NATIONAL            2        Toledo
#
# [36863 rows x 19 columns]

# %%
missing_values_absolute = df.isna().sum()
missing_values_percentage = (df.isna().mean()) * 100
missing_info = pd.DataFrame({'Missing Values': missing_values_absolute, 'Percentage': missing_values_percentage})
missing_info
# Out:
#                            Missing Values  Percentage
# id                                      0    0.000000
# date                                    0    0.000000
# price                                   0    0.000000
# quantity                             9118   24.734829
# region                               9152   24.827062
# product.id                              0    0.000000
# product.meta_product.id                 0    0.000000
# product.meta_product.name               0    0.000000
# product.meta_product.icon            1518    4.117950
# product.family.id                       0    0.000000
# product.family.name                     0    0.000000
# product.variety.id                      0    0.000000
# product.variety.name                    0    0.000000
# data_source.id                          0    0.000000
# data_source.name                        0    0.000000
# data_source.link                      947    2.568972
# data_source.kind                        0    0.000000
# province.id                             0    0.000000
# province.name                           0    0.000000

# %%
df = df[['date','product.meta_product.name','price','data_source.name','province.name']]

# %%
df.groupby(['product.meta_product.name','province.name']).count().reset_index().sort_values('date',ascending=False)
# Out:
#      product.meta_product.name  province.name  date  price  data_source.name
# 101                      Trigo         Toledo  8463   8463              8463
# 26                      Cebada         Toledo  4589   4589              4589
# 11                       Avena         Toledo  2921   2921              2921
# 61                        Maíz         Toledo  1590   1590              1590
# 116                      Yeros         Toledo  1140   1140              1140
# ..                         ...            ...   ...    ...               ...
# 65                      NAC 27         Cuenca     1      1                 1
# 79                Pipa Girasol  Internacional     1      1                 1
# 85   Sulfato Amonico Granulado         Cuenca     1      1                 1
# 16                      Cebada         Burgos     1      1                 1
# 0                     15-15-15         Cuenca     1      1                 1
#
# [117 rows x 5 columns]

# %%
# Convertir la columna 'date' al tipo de datos datetime
df['date'] = pd.to_datetime(df['date'],utc=True,format='mixed')

# Extraer solo la fecha de la columna 'date'
df['date'] = df['date'].dt.date
# Out:
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/2403979956.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'],utc=True,format='mixed')
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/2403979956.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].dt.date

# %%
df['dia']=pd.to_datetime(df['date']).dt.day
df['mes']=pd.to_datetime(df['date']).dt.month
df['anio']=pd.to_datetime(df['date']).dt.year
# Out:
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/989062315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dia']=pd.to_datetime(df['date']).dt.day
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/989062315.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mes']=pd.to_datetime(df['date']).dt.month
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/989062315.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anio']=pd.to_datetime(df['date']).dt.year

# %%
df['date'].max()
# Out:
# datetime.date(2024, 5, 29)

# %%
# Define mappings
dia_mapping = {
    1: 'uno',
    2: 'dos',
    3: 'tres',
    4: 'cuatro',
    5: 'cinco',
    6: 'seis',
    7: 'siete',
    8: 'ocho',
    9: 'nueve',
    10: 'diez',
    11: 'once',
    12: 'doce',
    13: 'trece',
    14: 'catorce',
    15: 'quince',
    16: 'dieciséis',
    17: 'diecisiete',
    18: 'dieciocho',
    19: 'diecinueve',
    20: 'veinte',
    21: 'veintiuno',
    22: 'veintidós',
    23: 'veintitrés',
    24: 'veinticuatro',
    25: 'veinticinco',
    26: 'veintiséis',
    27: 'veintisiete',
    28: 'veintiocho',
    29: 'veintinueve',
    30: 'treinta',
    31: 'treinta y uno'
}

mes_mapping = {
    1: 'enero',
    2: 'febrero',
    3: 'marzo',
    4: 'abril',
    5: 'mayo',
    6: 'junio',
    7: 'julio',
    8: 'agosto',
    9: 'septiembre',
    10: 'octubre',
    11: 'noviembre',
    12: 'diciembre'
}

anio_mapping = {
    2000: 'dos mil',
    2001: 'dos mil uno',
    2002: 'dos mil dos',
    2003: 'dos mil tres',
    2004: 'dos mil cuatro',
    2005: 'dos mil cinco',
    2006: 'dos mil seis',
    2007: 'dos mil siete',
    2008: 'dos mil ocho',
    2009: 'dos mil nueve',
    2010: 'dos mil diez',
    2011: 'dos mil once',
    2012: 'dos mil doce',
    2013: 'dos mil trece',
    2014: 'dos mil catorce',
    2015: 'dos mil quince',
    2016: 'dos mil dieciséis',
    2017: 'dos mil diecisiete',
    2018: 'dos mil dieciocho',
    2019: 'dos mil diecinueve',
    2020: 'dos mil veinte',
    2021: 'dos mil veintiuno',
    2022: 'dos mil veintidós',
    2023: 'dos mil veintitrés',
    2024: 'dos mil veinticuatro'
}

# Function to convert date components to strings
def convert_to_strings(row):
    dia_str = dia_mapping[row['dia']]
    mes_str = mes_mapping[row['mes']]
    anio_str = anio_mapping[row['anio']]
    return pd.Series([dia_str, mes_str, anio_str])

df['dia_str']=''
df['mes_str']=''
df['anio_str']=''

# Apply the conversion function to each row
df[['dia_str', 'mes_str', 'anio_str']] = df[['dia', 'mes', 'anio']].apply(convert_to_strings, axis=1)
# Out:
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/3557344952.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dia_str']=''
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/3557344952.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mes_str']=''
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/3557344952.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anio_str']=''
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/3557344952.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['dia_str', 'mes_str', 'anio_str']] = df[['dia', 'mes', 'anio']].apply(convert_to_strings, axis=1)

# %%
df['first_line']=''
# Crear la columna deseada con la estructura especificada
df['first_line'] = df.apply(lambda row: 
    f'precio: {row["price"]} fecha: {row["date"]}', 
    axis=1)
# Out:
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/2021525869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first_line']=''
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/2021525869.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first_line'] = df.apply(lambda row:

# %%
df.columns
# Out:
# Index(['date', 'product.meta_product.name', 'price', 'data_source.name',
#        'province.name', 'dia', 'mes', 'anio', 'dia_str', 'mes_str', 'anio_str',
#        'first_line'],
#       dtype='object')

# %%
df.rename(columns={'product.meta_product.name':'name_product','data_source.name':'source','province.name':'province'},inplace=True)
# Out:
# /var/folders/13/vtwv0p951k11cf7tvhd750jw0000gn/T/ipykernel_29608/2806391896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'product.meta_product.name':'name_product','data_source.name':'source','province.name':'province'},inplace=True)

# %%
df = df[['name_product','price','source','province']]

# %%
df.head(2)
# Out:
#   name_product  price         source province
# 0    Triticale  217.0  Lonja de León     León
# 1        Avena  270.0  Lonja de León     León

# %%
df.province.value_counts()
# Out:
# province
# Toledo            21671
# Sevilla            3921
# Albacete           2318
# León               2214
# Barcelona           839
# Palencia            776
# Ciudad Real         637
# Lleida              585
# Zaragoza            585
# París               551
# Salamanca           529
# Segovia             400
# Valladolid          394
# Cuenca              385
# Burgos              384
# Córdoba             295
# Zamora              293
# Estados Unidos       74
# Internacional         8
# Murcia                1
# Navarra               1
# Cáceres               1
# Huelva                1
# Name: count, dtype: int64

# %%
df
# Out:
#       name_product   price           source province
# 0        Triticale  217.00    Lonja de León     León
# 1            Avena  270.00    Lonja de León     León
# 2          Centeno  188.00    Lonja de León     León
# 3             Maíz  218.00    Lonja de León     León
# 4            Trigo  227.00    Lonja de León     León
# ...            ...     ...              ...      ...
# 36858        Trigo  180.30  Lonja de Toledo   Toledo
# 36859        Trigo  147.25  Lonja de Toledo   Toledo
# 36860        Trigo  171.29  Lonja de Toledo   Toledo
# 36861        Trigo  153.26  Lonja de Toledo   Toledo
# 36862        Trigo  171.29  Lonja de Toledo   Toledo
#
# [36863 rows x 4 columns]

# %% [markdown]
# # Database Creation

# %%
conn = sqlite3.connect('../data/abastores.db')
df.to_sql('abastores_data', conn, if_exists='replace', index=False)
# Out:
# 36801
